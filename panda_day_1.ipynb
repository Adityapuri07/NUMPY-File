# %%
a=20
b=20
print(a+b)
# Out:
# 40

# %% [markdown]
# # New Section

# %%
vv=input("yur name please")
print(vv)
# Out:
# yur name pleaseaditya
# aditya

# %%
# data frame in pandas
import pandas as pd
data = pd.DataFrame({
    'A':[1,2,3,4,5],
    'B':[2,3,4,4,8]
})
data
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4
# 3  4  4
# 4  5  8

# %%
data['age']=[12,3,4,4,45]
data
# Out:
#    A  B  age
# 0  1  2   12
# 1  2  3    3
# 2  3  4    4
# 3  4  4    4
# 4  5  8   45

# %%
import pandas as pd
pd.read_csv('')

# %%
import pandas as pd
data= pd.DataFrame({
    "A":[1,2,3,4,5],
    "b":[6,7,8,9,10]
})
data
# Out:
#    A   b
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
import pandas as pd
ser1 = pd.Series([99,9,0,8])
data1=pd.DataFrame({
   "maths":[20,30,50,55],
   "science":[30,50,50,80],
   "teacher_name":["mr","mrs","mrs","mr"] ,
   'ser1':ser1
})
data1
# Out:
#    maths  science teacher_name  ser1
# 0     20       30           mr    99
# 1     30       50          mrs     9
# 2     50       50          mrs     0
# 3     55       80           mr     8

# %%
import pandas as pd
hello=pd.Series([2,5,8])
data=pd.DataFrame({
    "NAME":["JOHN" ,"DAVID","ELIZA"],
    "PERCENTAGE":[90,88,95],
    'helo':hello

})
data
# Out:
#     NAME  PERCENTAGE  helo
# 0   JOHN          90     2
# 1  DAVID          88     5
# 2  ELIZA          95     8

# %%
data['science']
# Out:
# 0    30
# 1    50
# 2    50
# 3    80
# Name: science, dtype: int64

# %%
data["teacher_name"=
# Out:
# 0     mr
# 1    mrs
# 2    mrs
# 3     mr
# Name: teacher_name, dtype: object

# %%
emp_id=data["teacher_name"]
emp_id
# Out:
# 0     mr
# 1    mrs
# 2    mrs
# 3     mr
# Name: teacher_name, dtype: object

# %%
hello=pd.Series([2,5,8,66])
hello
# Out:
# 0     2
# 1     5
# 2     8
# 3    66
# dtype: int64

# %%
data1['science'],.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51662290523d> in <cell line: 1>()
# ----> 1 data1[['science','maths']].max()
#
# NameError: name 'data1' is not defined

# %%
data1[["science","maths"]].describe()
# Out:
#          science     maths
# count   4.000000   4.00000
# mean   52.500000  38.75000
# std    20.615528  16.52019
# min    30.000000  20.00000
# 25%    45.000000  27.50000
# 50%    50.000000  40.00000
# 75%    57.500000  51.25000
# max    80.000000  55.00000

# %%
import pandas as pd
ser2=pd.Series([20,50])
details=pd.DataFrame({
    "name":["john","david"],
    "percentage":[80,90],
    "phy":[80,90],
    "chemistry":[90,50],
    "id":ser2
})
details
# Out:
#     name  percentage  phy  chemistry  id
# 0   john          80   80         90  20
# 1  david          90   90         50  50

# %% [markdown]
# give me the DATA of person who get highest number in physics

# %%
details[details['chemistry']==details['chemistry'].max()]
# Out:
#    name  percentage  phy  chemistry  id
# 0  john          80   80         90  20

# %%
details.max()
# Out:
# name          john
# percentage      90
# phy             90
# chemistry       90
# id              50
# dtype: object

# %%
details['phy'].min()
# Out:
# 80

# %%
details.describe()
# Out:
#        percentage        phy  chemistry         id
# count    2.000000   2.000000   2.000000   2.000000
# mean    85.000000  85.000000  70.000000  35.000000
# std      7.071068   7.071068  28.284271  21.213203
# min     80.000000  80.000000  50.000000  20.000000
# 25%     82.500000  82.500000  60.000000  27.500000
# 50%     85.000000  85.000000  70.000000  35.000000
# 75%     87.500000  87.500000  80.000000  42.500000
# max     90.000000  90.000000  90.000000  50.000000

# %%
ser2=pd.Series([20,50])
ser2
# Out:
# 0    20
# 1    50
# dtype: int64

# %%
data = pd.read_excel('/content/Bike Sales Dashboard.xlsx',encoding='latin-1')
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-6c8970348c9e> in <cell line: 1>()
# ----> 1 data = pd.read_excel('/content/Bike Sales Dashboard.xlsx',encoding='latin-1')
#       2 data
#
# TypeError: read_excel() got an unexpected keyword argument 'encoding'

# %%
mc=pd.read_csv('/content/Student_performance_data _ (1).csv')

# %%
mc
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
mc.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
mc.tail()
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# ...

# %%
mc.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
mc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
mc['GPA']
# Out:
# 0       2.929196
# 1       3.042915
# 2       0.112602
# 3       2.054218
# 4       1.288061
#           ...
# 2387    3.455509
# 2388    3.279150
# 2389    1.142333
# 2390    1.803297
# 2391    2.140014
# Name: GPA, Length: 2392, dtype: float64

# %%
mc[(mc['Age']>15) & (mc['Gender']==1)]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# 9          1010   16       1          0                  1        18.444466
# 14         1015   18       1          0                  1        11.197811
# ...         ...  ...     ...        ...                ...              ...
# 2385       3386   16       1          0                  1         1.445434
# 2387       3388   18       1          0                  3        10.680555
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
mc[(mc["Age"]>17)& (mc["Gender"]==1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72675ccf54d1> in <cell line: 1>()
# ----> 1 mc[(mc["Age"]>17)& (mc["Gender"]==1)]
#
# NameError: name 'mc' is not defined

# %%
mc[mc["Age"]==15]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2          1003   15       0          2                  3         4.210570
# 6          1007   15       0          1                  1        15.601680
# 7          1008   15       1          1                  4        15.424496
# 15         1016   15       0          0                  2         9.728101
# 21         1022   15       0          0                  2        15.323142
# ...         ...  ...     ...        ...                ...              ...
# 2367       3368   15       1          3                  1         9.381207
# 2368       3369   15       0          0                  4         6.682728
# 2378       3379   15       1          0                  2        12.905555
# 2381       3382   15       0          2                  0        10.095086
# 2384       3385   15       1          0                  1        16.655581
#
# ...

# %%
mc.
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
mc[[	"StudentID",	"Age",	"Gender"]]
# Out:
#       StudentID  Age  Gender
# 0          1001   17       1
# 1          1002   18       0
# 2          1003   15       0
# 3          1004   17       1
# 4          1005   17       1
# ...         ...  ...     ...
# 2387       3388   18       1
# 2388       3389   17       0
# 2389       3390   16       1
# 2390       3391   16       1
# 2391       3392   16       1
#
# [2392 rows x 3 columns]

# %%
mc[	"Age"]
# Out:
# 0       17
# 1       18
# 2       15
# 3       17
# 4       17
#         ..
# 2387    18
# 2388    17
# 2389    16
# 2390    16
# 2391    16
# Name: Age, Length: 2392, dtype: int64

# %%
mc[(mc['Age']>16)&(mc["Gender"]==1)]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# 14         1015   18       1          0                  1        11.197811
# 17         1018   18       1          0                  0         3.528238
# ...         ...  ...     ...        ...                ...              ...
# 2370       3371   18       1          2                  1         2.912575
# 2371       3372   18       1          0                  3         0.668760
# 2376       3377   17       1          2                  2        14.667230
# 2379       3380   18       1          0                  2        16.534553
# 2387       3388   18       1          0                  3        10.680555
#
# ...

# %%
mc[mc['StudentID']==1003]
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2       1003   15       0          2                  3          4.21057
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2        26         0                2                0       0      0
#
#    Volunteering       GPA  GradeClass
# 2             0  0.112602         4.0

# %%
mc[mc["Ethnicity"]==2]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2          1003   15       0          2                  3         4.210570
# 30         1031   15       0          2                  2         5.055317
# 37         1038   15       0          2                  1        10.182268
# 39         1040   17       1          2                  1        12.233114
# 50         1051   17       1          2                  2        17.186499
# ...         ...  ...     ...        ...                ...              ...
# 2370       3371   18       1          2                  1         2.912575
# 2374       3375   16       0          2                  1         2.313504
# 2376       3377   17       1          2                  2        14.667230
# 2381       3382   15       0          2                  0        10.095086
# 2383       3384   16       1          2                  2        11.736409
#
# ...

# %%
mc.loc[mc['Gender']==1,'StudentID']
# Out:
# 0       1001
# 3       1004
# 4       1005
# 7       1008
# 9       1010
#         ...
# 2385    3386
# 2387    3388
# 2389    3390
# 2390    3391
# 2391    3392
# Name: StudentID, Length: 1222, dtype: int64

# %%
mc.shape
# Out:
# (2392, 15)

# %%
mc[['StudentID',	'Age',	'Gender']]
# Out:
#       StudentID  Age  Gender
# 0          1001   17       1
# 1          1002   18       0
# 2          1003   15       0
# 3          1004   17       1
# 4          1005   17       1
# ...         ...  ...     ...
# 2387       3388   18       1
# 2388       3389   17       0
# 2389       3390   16       1
# 2390       3391   16       1
# 2391       3392   16       1
#
# [2392 rows x 3 columns]

# %%
mc.iloc[:,2:3] = 'female'
# [row,column]

# %%
mc.loc[mc["Age"]>='17',"StudentID"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ef2db7eee223> in <cell line: 1>()
# ----> 1 mc.loc[mc["Age"]>='17',"StudentID"]
#
# NameError: name 'mc' is not defined

# %%
mc
# Out:
#      StudentID   Age  Gender Ethnicity ParentalEducation  StudyTimeWeekly  \
# 0         anon  anon  female      anon              anon        19.833723
# 1         anon  anon  female      anon              anon        15.408756
# 2         anon  anon  female      anon              anon         4.210570
# 3         anon  anon  female      anon              anon        10.028829
# 4         anon  anon  female      anon              anon         4.672495
# ...        ...   ...     ...       ...               ...              ...
# 2387      anon  anon  female      anon              anon        10.680555
# 2388      anon  anon  female      anon              anon         7.583217
# 2389      anon  anon  female      anon              anon         6.805500
# 2390      anon  anon  female      anon              anon        12.416653
# 2391      anon  anon  female      anon              anon        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# ...

# %%
import pandas as pd
marks=pd.Series([50,20,30,40])
pandda =pd.DataFrame({
    "name":["john","david","beckam","ausi"],
    "empid":[1001,1002,1003,1004],
    "country":["aus","nz","usa","norway"],
    "department":["science","computer","physical","maths"],
    'marks':marks
})
pandda
# Out:
#      name  empid country department  marks
# 0    john   1001     aus    science     50
# 1   david   1002      nz   computer     20
# 2  beckam   1003     usa   physical     30
# 3    ausi   1004  norway      maths     40

# %%
pandda["average"]=pandda["marks"]*5
pandda
# Out:
#      name  empid country department  marks  average
# 0    john   1001     aus    science     50      250
# 1   david   1002      nz   computer     20      100
# 2  beckam   1003     usa   physical     30      150
# 3    ausi   1004  norway      maths     40      200

# %%
pandda
# Out:
#      name  empid country department  marks  average
# 0    john   1001     aus    science     50      250
# 1   david   1002      nz   computer     20      100
# 2  beckam   1003     usa   physical     30      150
# 3    ausi   1004  norway      maths     40      200

# %%
from os import rename
pandda.rename(columns={'department':'my_dercr'})
# Out:
#      name  empid country  my_dercr  marks  average
# 0    john   1001     aus   science     50      250
# 1   david   1002      nz  computer     20      100
# 2  beckam   1003     usa  physical     30      150
# 3    ausi   1004  norway     maths     40      200

# %%
pandda['name']+'john'
# Out:
# 0      johnjohn
# 1     davidjohn
# 2    beckamjohn
# 3      ausijohn
# Name: name, dtype: object

# %%
marks=pd.Series([50,20,30,40])
marks
# Out:
# 0    50
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pandda['average'].mean()
# Out:
# 175.0

# %%
user=pd.read_csv('/content/tested.csv')

# %%
user
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
user.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    152
# male      266
# Name: Sex, dtype: int64

# %%
user['Sex'].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
user['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
user["Pclass"].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
import pandas as pd
data = {'item' :['tea','coffee','sugar','tea','coffee','sugar','tea','coffee','sugar'],
        'year':[2010,2010,2010,2011,2011,2011,2012,2012,2012],
        'sales':[1200,1050,500,1500,1200,1000,1230,1300,1420]}
df = pd.DataFrame(data,columns=['item','year','sales'])
df
# Out:
#      item  year  sales
# 0     tea  2010   1200
# 1  coffee  2010   1050
# 2   sugar  2010    500
# 3     tea  2011   1500
# 4  coffee  2011   1200
# 5   sugar  2011   1000
# 6     tea  2012   1230
# 7  coffee  2012   1300
# 8   sugar  2012   1420

# %%
df.groupby('item').count()
# Out:
#         year  sales
# item
# coffee     3      3
# sugar      3      3
# tea        3      3

# %%
user["Fare"].mean()
# Out:
# 35.627188489208635

# %%
user[["Age","Fare"]].median()
# Out:
# Age     27.0000
# Fare    14.4542
# dtype: float64

# %%
user.agg({
    "Age":["min","max","median","mean"],
    "Fare":["min","max","median","mean"]
})
# Out:
#              Age        Fare
# min      0.17000    0.000000
# max     76.00000  512.329200
# median  27.00000   14.454200
# mean    30.27259   35.627188

# %%
import pandas as pd
import numpy as np
data=pd.DataFrame({
    "A":[1,2,3,4,5],
    "B":[2,3,np.nan,4,8],
    "C":[2,3,4,np.nan,np.nan],
    "d":[2,3,4,5,np.nan]
})
data
# Out:
#    A    B    C    d
# 0  1  2.0  2.0  2.0
# 1  2  3.0  3.0  3.0
# 2  3  NaN  4.0  4.0
# 3  4  4.0  NaN  5.0
# 4  5  8.0  NaN  NaN

# %%
data.dropna()
# Out:
#    A    B    C    d
# 0  1  2.0  2.0  2.0
# 1  2  3.0  3.0  3.0

# %%
data.fillna(data.mean())
# Out:
#    A     B    C    d
# 0  1  2.00  2.0  2.0
# 1  2  3.00  3.0  3.0
# 2  3  4.25  4.0  4.0
# 3  4  4.00  3.0  5.0
# 4  5  8.00  3.0  3.5

# %%
data['B'].fillna(data['B'].mean())
# Out:
# 0    2.00
# 1    3.00
# 2    4.25
# 3    4.00
# 4    8.00
# Name: B, dtype: float64

# %% [markdown]
# # New Section

# %%
data
# Out:
#    A    B    C    d
# 0  1  2.0  2.0  2.0
# 1  2  3.0  3.0  3.0
# 2  3  NaN  4.0  4.0
# 3  4  4.0  NaN  5.0
# 4  5  8.0  NaN  NaN

# %%
data["C"].fillna(data["C"].mean())
# Out:
# 0    2.0
# 1    3.0
# 2    4.0
# 3    3.0
# 4    3.0
# Name: C, dtype: float64

# %%
data
# Out:
#    A    B    C    d
# 0  1  2.0  2.0  2.0
# 1  2  3.0  3.0  3.0
# 2  3  NaN  4.0  4.0
# 3  4  4.0  NaN  5.0
# 4  5  8.0  NaN  NaN

# %%
data.dropna()
# Out:
#    A    B    C    d
# 0  1  2.0  2.0  2.0
# 1  2  3.0  3.0  3.0
